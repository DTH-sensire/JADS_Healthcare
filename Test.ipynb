# %% [markdown]
# <a href="https://colab.research.google.com/github/DTH-sensire/JADS_Healthcare/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test

# %% [markdown]
# # Nieuwe sectie

# %% [markdown]
# Eerst GIT connectie voor de bestanden

# %%
# !git clone https://github.com/DTH-sensire/JADS_Healthcare
# Out:
# Cloning into 'JADS_Healthcare'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), 4.37 MiB | 10.27 MiB/s, done.

# %% [markdown]
# Read and profiling

# %%
import pandas as pd

# %%
df = pd.read_parquet("/content/JADS_Healthcare/knee-provider.parquet")

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title='PROMS', explorative=True)

# %%
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile.to_file(output_file='/content/JADS_Healthcare/NHS_PROMS_profiling.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
